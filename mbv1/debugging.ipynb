# %%
import torch

checkpoint_path = "split/saved_models/custom/rosenbrock_0.pth.tar"

checkpoint = torch.load(checkpoint_path, weights_only=False)

# %%
import torch
import pickle

result_path = "result/rosenbrock_0_result.pkl" 
ckpt = pickle.load(open(result_path, 'rb'))

# %%
ckpt
# Out:
# [tensor(0.5458, device='cuda:0'), tensor(0.5458, device='cuda:0')]
